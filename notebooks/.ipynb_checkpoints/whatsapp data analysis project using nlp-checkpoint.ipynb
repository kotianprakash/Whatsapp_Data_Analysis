# %% [markdown]
# ## <center><a>Whatsapp Data Analysis </a></center>

# %% [markdown]
# The project started off with basic data analyses, namely getting means and sums of different statistics such as average number of words per message per user and eventually evolved into analyzing topics that were frequently discussed in the chat.

# %% [raw]
# step 1 : create env
#     conda create --name watsapp python=3.6
#
# step 2 : activate env
#
#     conda activate watsapp
#
# step :
#     cd to wirk dir (requirements.txt should present )
#     (watsapp) user> pip install -r requirements.txt
#
# step 4:
#     > pip install ipykernel
#     > python -m ipykernel install --user --name watsapp --display-name watsapp
#     > restart jupyter notebook

# %% [markdown]
# ## <a>Important Steps</a>
#
# 1. set mobile time format to 24hrs
# 2. open watsapp select any contact
# 3. click on 3 dots then click on more
# 4. click on export chart -> without media
# 5. copy .txt chat file and paste it in DATA folder

# %% [markdown]
# ## <a>Functions</a>

# %% [markdown]
# I imported all packages manually just to show you which are which and how they work.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.insert(0,'..')  # Needed to import package in parent dir, remove this if you pip installed the package
from utils.whatsapp import helper      # Helper to prepare the data
from utils.whatsapp import general     # General statistics
from utils.whatsapp import tf_idf      # To calculate TF-IDF
from utils.whatsapp import emoji       # To analyze emoji use
from utils.whatsapp import topic       # Topic modelling and summarization
from utils.whatsapp import sentiment   # Sentiment Analysis
from utils.whatsapp import wordcloud   # Create Word Clouds\

from utils.colors   import colors      # Frequent Color Visualization

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\prakash
# [nltk_data]     kotian\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\prakash
# [nltk_data]     kotian\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## <a>General Statistics</a>

# %% [markdown]
# Here you can find general data with regards to whatsapp conversations such as the number of messages and words. this is simply to get a general understanding of the conversations.

# %% [markdown]
# #### <a>Prepare Data</a>

# %% [markdown]
# The data is preprocessed by loading in the raw txt file which is sent through whatsapp to your mail. The following columns are created:
# * Message_Raw
#     * The raw message for each user (including date and name of user)
# * User
#     * The user who has sent the message, if no users have sent that message
#     then it is simply removed from the dataframe
# * Message_Clean
#     * Only containing the message, but with all possible symbols in there
#     Thus, no date and no name of the user
# * Message_Only_Text
#     * Only text, lowercase
# * Date
#     * Date in the format y/m/d

# %%
df = helper.import_data(r"C:\Users\prakash kotian\Desktop\Data_Science\Deep Learning\WatsApp Project\data\WhatsApp Chat with Mami.txt")

# %%
df.shape # total number of messeges is 1156
# Out:
# (480, 3)

# %%
df.head(20)
# Out:
#     index                                        Message_Raw  \
# 0       0  3/27/22, 22:06 - Messages and calls are end-to...
# 1       0                    3/27/22, 22:06 - Mami: Bhanje\n
# 2       1  3/27/22, 22:06 - Mami: Kaunsa airdopes acha ha...
# 3       2               3/27/22, 22:06 - Mami: Boat ka kya\n
# 4       3        3/27/22, 22:07 - Mami: Tere pass Hain kya\n
# 5       4                        3/27/22, 22:09 - Mami: Ok\n
# 6       5                 3/27/22, 22:09 - Mami: U have na\n
# 7       6  3/27/22, 22:12 - Mami: Maine boat ka 1500 ka b...
# 8       7                     3/27/22, 22:12 - Mami: Woh ?\n
# 9       8              3/27/22, 22:12 - Mami: Not nice kya\n
# 10      9  3/27/22, 22:12 - Mami: Acha yeh latest hain kya\n
# 11     10               3/27/22, 22:13 - Mami: New arrival\n
# 12     11                       3/27/22, 22:13 - Mami: Kya\n
# 13     12  3/27/22, 22:13 - Mami: Mere liye khana pakayeg...
# 14     13                     3/27/22, 22:16 - Mami: Is it\n
# 15     14               3/27/22, 22:16 - Mami: Sound proof\n
# 16     15       3/27/22, 22:16 - Mami: Danger hainnwoh bhi\n
# 17     16           3/27/22, 22:16 - Mami: My niece roshni\n
# 18     17  3/27/22, 22:16 - Mami: Khaan mein earphone lag...
# 19     18  3/27/22, 22:17 - Mami: Peeche se koi bhi chill...
#
#                                                  User
# 0   Messages and calls are end-to-end encrypted. N...
# 1                                                Mami
# 2                                                Mami
# 3                                                Mami
# 4                                                Mami
# 5                                                Mami
# 6                                                Mami
# 7                                                Mami
# 8                                                Mami
# 9                                                Mami
# 10                                               Mami
# 11                                               Mami
# 12                                               Mami
# 13                                               Mami
# 14                                               Mami
# 15                                               Mami
# 16                                               Mami
# 17                                               Mami
# 18                                               Mami
# 19                                               Mami

# %%
df.columns
# Out:
# Index(['index', 'Message_Raw', 'User'], dtype='object')

# %%
df = helper.preprocess_data(df)

# %%
df.head(10)
# Out:
#      index                                        Message_Raw      User  \
# 1        0                    3/27/22, 22:06 - Mami: Bhanje\n      Mami
# 2        1  3/27/22, 22:06 - Mami: Kaunsa airdopes acha ha...      Mami
# 3        2               3/27/22, 22:06 - Mami: Boat ka kya\n      Mami
# 247      0  3/27/22, 22:07 - Prakash😎: Ruko  dek kar bolta...  Prakash😎
# 4        3        3/27/22, 22:07 - Mami: Tere pass Hain kya\n      Mami
# 5        4                        3/27/22, 22:09 - Mami: Ok\n      Mami
# 6        5                 3/27/22, 22:09 - Mami: U have na\n      Mami
# 248      1      3/27/22, 22:11 - Prakash😎: Haa Mera pass hy\n  Prakash😎
# 251      4         3/27/22, 22:12 - Prakash😎: But costly hy\n  Prakash😎
# 250      3        3/27/22, 22:12 - Prakash😎: Yeh wala aacha\n  Prakash😎
#
#                  Message_Clean          Message_Only_Text                Date  \
# 1                       Bhanje                     bhanje 2022-03-27 22:06:00
# 2    Kaunsa airdopes acha hain  kaunsa airdopes acha hain 2022-03-27 22:06:00
# 3                  Boat ka kya                boat ka kya 2022-03-27 22:06:00
# 247     Ruko  dek kar bolta hu     ruko  dek kar bolta hu 2022-03-27 22:07:00
# 4           Tere pass Hain kya         tere pass hain kya 2022-03-27 22:07:00
# 5                           Ok                         ok 2022-03-27 22:09:00
# 6                    U have na                  u have na 2022-03-27 22:09:00
# 248           Haa Mera pass hy           haa mera pass hy 2022-03-27 22:11:00
# 251              But costly hy              but costly hy 2022-03-27 22:12:00
# 250             Yeh wala aacha             yeh wala aacha 2022-03-27 22:12:00
#
#      Hour  Day_of_Week
# 1      22            6
# 2      22            6
# 3      22            6
# 247    22            6
# 4      22            6
# 5      22            6
# 6      22            6
# 248    22            6
# 251    22            6
# 250    22            6

# %%
df.columns
# Out:
# Index(['index', 'Message_Raw', 'User', 'Message_Clean', 'Message_Only_Text',
#        'Date', 'Hour', 'Day_of_Week'],
#       dtype='object')

# %%
df["Message_Raw"][:30]
# Out:
# 1                        3/27/22, 22:06 - Mami: Bhanje\n
# 2      3/27/22, 22:06 - Mami: Kaunsa airdopes acha ha...
# 3                   3/27/22, 22:06 - Mami: Boat ka kya\n
# 247    3/27/22, 22:07 - Prakash😎: Ruko  dek kar bolta...
# 4            3/27/22, 22:07 - Mami: Tere pass Hain kya\n
# 5                            3/27/22, 22:09 - Mami: Ok\n
# 6                     3/27/22, 22:09 - Mami: U have na\n
# 248        3/27/22, 22:11 - Prakash😎: Haa Mera pass hy\n
# 251           3/27/22, 22:12 - Prakash😎: But costly hy\n
# 250          3/27/22, 22:12 - Prakash😎: Yeh wala aacha\n
# 9                  3/27/22, 22:12 - Mami: Not nice kya\n
# 8                         3/27/22, 22:12 - Mami: Woh ?\n
# 7      3/27/22, 22:12 - Mami: Maine boat ka 1500 ka b...
# 10     3/27/22, 22:12 - Mami: Acha yeh latest hain kya\n
# 11                  3/27/22, 22:13 - Mami: New arrival\n
# 12                          3/27/22, 22:13 - Mami: Kya\n
# 254       3/27/22, 22:13 - Prakash😎: Extra features hy\n
# 253    3/27/22, 22:13 - Prakash😎: Is bus extra featur...
# 252      3/27/22, 22:13 - Prakash😎: Haa wo bii accha h\n
# 13     3/27/22, 22:13 - Mami: Mere liye khana pakayeg...
# 255    3/27/22, 22:14 - Prakash😎: dusra Log  kya bole...
# 17              3/27/22, 22:16 - Mami: My niece roshni\n
# 258      3/27/22, 22:16 - Prakash😎: Raod mei danger hy\n
# 18     3/27/22, 22:16 - Mami: Khaan mein earphone lag...
# 16          3/27/22, 22:16 - Mami: Danger hainnwoh bhi\n
# 15                  3/27/22, 22:16 - Mami: Sound proof\n
# 14                        3/27/22, 22:16 - Mami: Is it\n
# 257                     3/27/22, 22:16 - Prakash😎: Haa\n
# 256           3/27/22, 22:16 - Prakash😎: iska khasiyat\n
# 259                       3/27/22, 22:17 - Prakash😎: 😂\n
# Name: Message_Raw, dtype: object

# %%
df['Message_Clean'][:]
# Out:
# 1                                   Bhanje
# 2                Kaunsa airdopes acha hain
# 3                              Boat ka kya
# 247                 Ruko  dek kar bolta hu
# 4                       Tere pass Hain kya
#                       ...
# 242                       Mazze leke pura👍
# 243                                     ❣️
# 244    Pls send me the pics including this
# 245                            Oi ma.....!
# 246                No dress shape not good
# Name: Message_Clean, Length: 332, dtype: object

# %%
# Change labels for anonymization - Leave this at False
if True:
    user_labels = {old: new for old, new in zip(sorted(df.User.unique()), ['Prakash😎', 'Mami'])}
    df.User = df.User.map(user_labels)

# %% [markdown]
# #### <a> Users in the group</a>

# %%
general.print_users(df)
# Out:
# #############
# ##  Users  ##
# #############
#
# Prakash😎
# Mami

# %% [markdown]
# #### <a> Users in the group</a>

# %%
general.plot_messages(df, colors=None, trendline=False, savefig=False, dpi=100)

# %% [markdown]
# #### <a>Active Moments</a>

# %% [markdown]
# **Daily Activity**
# This shows the daily activity per person in a spider plot and in total in a histogram.
# NOTE: This is unstandardized data, which means that it also shows the amount of messages.

# %%
general.plot_day_spider(df, colors=None, savefig=False, dpi=100)

# %%
general.plot_active_days(df, savefig=False, dpi=100, user='Prakash😎')
general.plot_active_days(df, savefig=False, dpi=100, user='Mami')

# %% [markdown]
# **Hourly Activity**
# It shows which days are most active based on the period in which most messages are send.

# %%
general.plot_active_hours(df, color='#ffdfba', savefig=False, dpi=100, user='All')

# %% [markdown]
# **Calendar Map**
# Here you can choose for which year you want to see the activity

# %%
import pandas as pd
years = set(pd.DatetimeIndex(df.Date.values).year)

for year in years:
    general.calendar_plot(df, year=year, how='count', column='index')

# %% [markdown]
# #### <a>Averages / Summaries</a>

# %% [markdown]
# Here you can find general averages and summaries. For those that are interested how often a person said "I love you", you can also find that.

# %%
general.print_stats(df, love=False)
# Out:
# ##########################
# ##  Number of Messages  ##
# ##########################
#
# 221	Prakash😎
# 111	Mami
#
# #######################
# ##  Number of Words  ##
# #######################
#
# 843	Prakash😎
# 392	Mami
#
# #########################
# ##  Messages per hour  ##
# #########################
#
# Prakash😎:	0.03223924142961342
# Mami:	0.016517857142857143
#
# ################################
# ##  Avg nr Words per Message  ##
# ################################
#
# Prakash😎: 3.81
# Mami: 3.53
#
# #############################
# ##  Avg length of Message  ##
# #############################
#
# Prakash😎: 17.98
# Mami: 15.02
#
# ##############################
# ##  Highscore Day per User  ##
# ##############################
#
# Prakash😎
# Messages: 	27
# Day: 		2022-03-27
#
# Mami
# Messages: 	14
# Day: 		2022-03-27

# %% [markdown]
# #### <a>Response Time</a>

# %%
general.print_timing(df)
# Out:
# #####################################
# ##  Avg. Response Time in Minutes  ##
# #####################################
#
# Prakash😎:                     41.34
# Mami:                         19.77
#
# ##############################
# ##  Nr. Initiated Messages  ##
# ##############################
#
# Prakash😎:                     9		(4.07% of all messages)
# Mami:                         7		(6.31% of all messages)

# %% [markdown]
# ## <a >TF-IDF</a>

# %% [markdown]
# #### <a>Create Count Vector</a>

# %% [markdown]
# It creates the dataframe "counts" which is a dataframe that contains each word that is said in all conversations and counts how often each user has said that word.

# %%
counts = tf_idf.count_words_per_user(df, sentence_column="Message_Only_Text", user_column="User")
counts = tf_idf.remove_stopwords(counts, language="english", column="Word")

# %%
counts[:30]
# Out:
#         Word  Prakash😎  Mami
# 1     kaunsa         2     0
# 2   airdopes         1     0
# 3       acha         7     0
# 4       hain        16     1
# 5       boat         2     0
# 6         ka        15    10
# 7        kya        15     1
# 8       ruko         0     1
# 10       dek         0     1
# 11       kar         3     2
# 12     bolta         0     1
# 13        hu         0     4
# 14      tere         1     0
# 15      pass         2     1
# 16        ok        15     0
# 19        na         8     1
# 20       haa         0    14
# 21      mera         0     1
# 22        hy         0    23
# 24    costly         0     1
# 25       yeh         4     4
# 26      wala         2     5
# 27     aacha         0     5
# 29      nice         4     0
# 30       woh         1     0
# 31     maine         1     0
# 32       bhi         4     0
# 33     dekha         1     0
# 34    latest         1     0
# 35       new         2     0

# %%
counts.loc[counts['Word']=="help"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-a9b001814e44> in <module>
# ----> 1 counts.loc[counts['Word']=="help"]
#
# AttributeError: 'dict' object has no attribute 'loc'

# %%
counts.loc[counts['Word']=="thanks"]
# Out:
# Empty DataFrame
# Columns: [Word, Prakash😎, Mami]
# Index: []

# %%
counts.loc[counts['Word']=="study"]
# Out:
# Empty DataFrame
# Columns: [Word, Prakash😎, Mami]
# Index: []

# %%
counts.loc[counts['Word']=="bye"]
# Out:
# Empty DataFrame
# Columns: [Word, Prakash😎, Mami]
# Index: []

# %%
counts.loc[counts['Word']=="job"]
# Out:
# Empty DataFrame
# Columns: [Word, Prakash😎, Mami]
# Index: []

# %% [markdown]
# #### <a>Unique Words</a>

# %%
unique_words = tf_idf.get_unique_words(counts, df, version = 'C')

# %%
unique_words
# Out:
#           Word  Prakash😎  Mami  Prakash😎_TF_IDF  Mami_TF_IDF  Prakash😎_Unique  \
# 1       kaunsa         2     0        15.343976     5.128694         2.991790
# 2     airdopes         1     0        11.619369     5.824106         1.995048
# 3         acha         7     0        30.879848     3.871837         7.975504
# 4         hain        16     1        50.527326     5.953555         8.486916
# 5         boat         2     0        15.343976     5.128694         2.991790
# ..         ...       ...   ...              ...          ...              ...
# 591       pura         1     0        11.619369     5.824106         1.995048
# 592       send         1     0        11.619369     5.824106         1.995048
# 593  including         1     0        11.619369     5.824106         1.995048
# 594         oi         1     0        11.619369     5.824106         1.995048
# 597      shape         1     0        11.619369     5.824106         1.995048
#
#      Mami_Unique
# 1       0.334248
# 2       0.501241
# 3       0.125384
# 4       0.117828
# 5       0.334248
# ..           ...
# 591     0.501241
# 592     0.501241
# 593     0.501241
# 594     0.501241
# 597     0.501241
#
# [537 rows x 7 columns]

# %% [markdown]
# #### <a>Plot Image</a>

# %%
tf_idf.print_users(df)
# Out:
# #############
# ##  Users  ##
# #############
#
# Prakash😎
# Mami

# %% [markdown]
# **Instructions**
# Make sure to change "user" in the function below to one of the users as seen above. It needs to be the exact same naming otherwise it will not work. Furthermore, a valid picture needs to be selected. You can choose the sizing yourself which might need some experimenting with before finding the right size. It also works with a link to the image online.

# %%
tf_idf.plot_unique_words(unique_words, 
                         user='Prakash😎', 
                         image_path='../images/dev.jpeg', # use '../images/mask.png' to use the standard image
                         image_url=None, 
                         title="Me", 
                         title_color="Blue", 
                         title_background='#AAAAAA', 
                         width=400, 
                         height=500)

# %%
tf_idf.plot_unique_words(unique_words, 
                         user="Mami", 
                         image_path='../images/mask.png', # use '../images/mask.png' to use the standard image
                         image_url=None, 
                         title="Ruzaan", 
                         title_color="Red", 
                         title_background='#AAAAAA', 
                         width=400, 
                         height=500)

# %% [markdown]
# # <a>Emoji Analysis</a>

# %% [markdown]
# These analysis are based on the Emojis used in each message. Below you can find the following:
# * Unique Emoji per user
# * Commonly used Emoji per user
# * Highly correlated Emoji per user

# %%
temp = df[['index', 'Message_Raw', 'User', 'Message_Clean', 'Message_Only_Text']].copy()
temp = emoji.prepare_data(temp)

# Count all emojis
counts = emoji.count_emojis(temp, non_unicode=True)

# Get unique emojis
list_of_words = [word for user in counts for word in counts[user]]
unique_emoji = emoji.get_unique_emojis(temp, counts, list_of_words)
del temp

# %% [markdown]
# #### <a>Unique and Common Emoji</a>

# %%
emoji.print_stats(unique_emoji, counts)
# Out:
# #############################
# ### Unique Emoji (TF-IDF) ###
# #############################
#
# Prakash😎
# :/ 0.5045045045045046
#
# Mami
# :/ 1.9821428571428574
#
# #########################
# ### Most Common Emoji ###
# #########################
#
# Prakash😎
# :/ 1
#
# Mami
# :/ 1

# %%
emoji.plot_counts(counts, user = "Prakash😎")
emoji.plot_counts(counts, user = "Mami")

# %% [markdown]
# #### <a>Correlation Matrix</a>

# %%
emoji.plot_corr_matrix(df, "Prakash😎", list_of_words, counts)

# %% [markdown]
# # <a>Topic Modelling</a>

# %%
df['Message_Only_Text'] # Use This column
# Out:
# 1                                   bhanje
# 2                kaunsa airdopes acha hain
# 3                              boat ka kya
# 247                 ruko  dek kar bolta hu
# 4                       tere pass hain kya
#                       ...
# 242                        mazze leke pura
# 243
# 244    pls send me the pics including this
# 245                                  oi ma
# 246                no dress shape not good
# Name: Message_Only_Text, Length: 332, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_df = 0.95, min_df=2, stop_words='english')
dtm = tfidf.fit_transform(df['Message_Only_Text'])

# %%
dtm   # so we have 1102 documents and 398 features
# Out:
# <332x136 sparse matrix of type '<class 'numpy.float64'>'
# 	with 529 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import NMF
nmf_model = NMF(n_components=7, random_state=42) # nmf is faster than lda 
nmf_model.fit(dtm)
# Out:
# NMF(n_components=7, random_state=42)

# %%
nmf_model.components_
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.94539861e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.29485982e-02,
#         0.00000000e+00, 0.00000000e+00, 2.61993865e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         4.77107855e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 3.16537229e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 3.02430213e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 2.14558498e-05, 0.00000000e+00,
#         0.00000000e+00, 2.73406561e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 5.65113997e-03, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.87755093e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.28711594e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.86316334e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.89492761e-02,
#         0.00000000e+00, 0.00000000e+00, 1.54940286e-03, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.64162168e-05, 4.94963556e-07,
#         0.00000000e+00, 0.00000000e+00, 1.82917489e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 3.06614825e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.23721896e-03,
#         0.00000000e+00, 0.00000000e+00, 2.12010004e-03, 0.00000000e+00,
#         0.00000000e+00, 1.67118088e-03, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.54173753e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 7.70220481e-02, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 8.73543306e-02, 9.68352995e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.90650646e-04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 6.81194277e-02, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.60594661e-03, 0.00000000e+00],
#        [1.51678560e-01, 0.00000000e+00, 0.00000000e+00, 4.37520159e-02,
#         0.00000000e+00, 1.15254852e-03, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         6.75671639e-03, 1.31043429e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 8.07603772e-02, 0.00000000e+00, 7.19979065e-02,
#         0.00000000e+00, 9.47037932e-02, 0.00000000e+00, 3.58641919e-02,
#         1.16040510e-03, 3.54651316e-02, 0.00000000e+00, 6.43627626e-02,
#         6.43627626e-02, 4.83288888e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.93177432e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         5.75644035e-03, 0.00000000e+00, 9.69756459e-02, 0.00000000e+00,
#         0.00000000e+00, 1.55654433e+00, 6.75671639e-03, 4.60170265e-03,
#         1.94739206e-01, 0.00000000e+00, 2.40438437e-03, 3.45756512e-05,
#         0.00000000e+00, 0.00000000e+00, 8.00912902e-03, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 3.31414977e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.87481201e-03,
#         0.00000000e+00, 0.00000000e+00, 4.72993934e-04, 0.00000000e+00,
#         2.43141289e-01, 1.68944643e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 6.18668893e-02, 1.13424391e-01, 9.90989197e-01,
#         0.00000000e+00, 0.00000000e+00, 7.19979065e-02, 0.00000000e+00,
#         0.00000000e+00, 6.89874729e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.80682880e-02, 0.00000000e+00, 0.00000000e+00,
#         1.59883122e-01, 7.28244845e-02, 6.11193734e-02, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.30378132e-01, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 5.10831234e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.53957563e-02, 1.77648893e-01,
#         0.00000000e+00, 3.49911708e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 4.31971760e-02, 7.66238157e-04,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.80682880e-02,
#         0.00000000e+00, 4.31377271e-03, 6.23856120e-02, 0.00000000e+00,
#         1.38752332e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         3.24297131e-06, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.50728563e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.65784223e-07, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         9.08282906e-06, 0.00000000e+00, 3.94467440e-59, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.28236520e-07, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 7.48300094e-03, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.24914528e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 9.99144740e-06, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.42803628e-07,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.75046549e-05, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.64633568e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 4.06274625e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.08128142e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 9.52052819e-06, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 7.46456596e-03, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.54090192e-01, 5.80439240e-04, 5.20555443e-02,
#         0.00000000e+00, 2.61250486e-02, 2.20966712e-03, 2.50279999e-02,
#         0.00000000e+00, 2.04741013e-01, 1.27821436e-01, 1.97746447e-03,
#         1.80724308e-01, 6.14432196e-03, 5.75394342e-02, 5.55177397e-02,
#         3.71434907e-03, 0.00000000e+00, 6.47283054e-04, 1.14545255e-02,
#         0.00000000e+00, 1.15915865e-03, 4.41256686e-02, 0.00000000e+00,
#         3.58816112e-33, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         3.96549752e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 8.79527142e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.44916988e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.15055571e-02,
#         0.00000000e+00, 5.42723188e-03, 3.39851480e-02, 8.42919872e-02,
#         9.72358825e-03, 1.73578033e-02, 3.71434907e-03, 0.00000000e+00,
#         2.57150574e-01, 8.84397854e-03, 1.41590833e+00, 5.88149637e-03,
#         0.00000000e+00, 6.53245813e-02, 0.00000000e+00, 8.77593983e-02,
#         6.45067460e-02, 0.00000000e+00, 0.00000000e+00, 7.12547337e-02,
#         0.00000000e+00, 0.00000000e+00, 1.43222556e-03, 1.89061380e-01,
#         2.28226576e-02, 2.98695172e-02, 1.01970362e-02, 1.13440191e-03,
#         0.00000000e+00, 0.00000000e+00, 1.96264671e-02, 0.00000000e+00,
#         0.00000000e+00, 4.22361444e-02, 5.16645006e-02, 7.25348538e-04,
#         9.03317273e-02, 1.28365361e-02, 1.35519162e-01, 0.00000000e+00,
#         8.94501474e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         5.61414268e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.71617677e-02,
#         1.17026418e-01, 0.00000000e+00, 9.58916083e-02, 0.00000000e+00,
#         4.88970871e-02, 3.68510230e-01, 0.00000000e+00, 2.36228631e-02,
#         4.54383005e-03, 6.69334590e-02, 5.27610585e-03, 1.85992763e-01,
#         2.00911284e-01, 0.00000000e+00, 0.00000000e+00, 6.99734209e-03,
#         0.00000000e+00, 9.99528568e-02, 1.34151476e-03, 2.76628891e-02,
#         1.04542078e-04, 3.69953610e-02, 0.00000000e+00, 4.75558087e-03,
#         2.23376269e-04, 2.28664878e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.41135148e-02, 4.05872549e-02, 0.00000000e+00,
#         4.72966252e-03, 0.00000000e+00, 5.39247939e-03, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.46852995e-04,
#         6.46065457e-01, 1.45426258e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 7.14100357e-02, 0.00000000e+00,
#         2.47145089e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.62683673e-03, 6.03723232e-02, 0.00000000e+00,
#         8.54955299e-04, 1.80579044e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.14529809e-01, 3.59755479e-03, 6.77987181e-02,
#         8.26294802e-03, 9.98754693e-04, 0.00000000e+00, 0.00000000e+00,
#         2.32383254e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.03970703e-03, 0.00000000e+00, 0.00000000e+00, 3.07939643e-03,
#         1.00302219e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.59396230e-03,
#         6.49471268e-02, 0.00000000e+00, 3.25358175e-03, 6.09906617e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         5.69697183e-02, 0.00000000e+00, 8.34331058e-02, 3.01693630e-01,
#         1.91032394e-03, 0.00000000e+00, 1.43978073e-02, 1.01150651e-03,
#         6.06783683e-03, 1.44321275e-03, 2.07859135e-02, 0.00000000e+00,
#         9.71845526e-02, 0.00000000e+00, 0.00000000e+00, 1.97857258e-04,
#         0.00000000e+00, 6.70170475e-01, 3.80760558e-03, 0.00000000e+00,
#         0.00000000e+00, 3.27192061e-03, 0.00000000e+00, 6.24648277e-46,
#         0.00000000e+00, 0.00000000e+00, 1.12433505e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.11183304e-02, 3.26904059e-03, 3.44019821e-02,
#         4.78893502e-02, 4.14657941e-03, 2.40702259e-02, 4.73236903e-02,
#         1.53719649e-03, 8.04797127e-03, 0.00000000e+00, 8.54516775e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.90287418e-02,
#         0.00000000e+00, 1.41908353e-01, 0.00000000e+00, 0.00000000e+00,
#         7.76867239e-02, 1.84010344e-03, 6.18723696e-02, 3.62358050e-02,
#         9.59979294e-03, 7.38664801e-04, 0.00000000e+00, 1.75669718e-03,
#         4.53911432e-05, 0.00000000e+00, 6.79591238e-03, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.17814634e-45,
#         6.63800666e-03, 0.00000000e+00, 1.00984841e-02, 1.56268668e-01],
#        [3.42985522e-02, 7.95171605e-03, 1.95220161e-04, 3.72601295e-02,
#         5.03393016e-01, 7.94641033e-02, 3.35541246e-02, 4.70897570e-02,
#         0.00000000e+00, 9.62020235e-04, 0.00000000e+00, 9.31274529e-04,
#         3.25311212e-02, 3.20684000e-03, 0.00000000e+00, 2.96125672e-02,
#         1.67571914e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.19144718e-01,
#         1.81505041e-02, 5.62721080e-03, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 9.93689735e-02, 2.33992030e-03, 2.67359769e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.86600745e-02,
#         8.88408932e-01, 2.48614451e-37, 0.00000000e+00, 6.59587164e-02,
#         6.50144745e-02, 0.00000000e+00, 0.00000000e+00, 1.37532732e-02,
#         8.22727219e-03, 0.00000000e+00, 1.67571914e-03, 6.64187595e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.55764542e-03,
#         2.59913802e-02, 5.22334406e-02, 1.13211923e-02, 0.00000000e+00,
#         0.00000000e+00, 5.07749755e-02, 1.43347602e-01, 5.53997336e-02,
#         9.85375799e-03, 1.96687999e-01, 0.00000000e+00, 0.00000000e+00,
#         8.46592166e-03, 1.00666553e+00, 3.54847309e-03, 6.10184828e-02,
#         0.00000000e+00, 4.29948533e-02, 0.00000000e+00, 3.84133833e-37,
#         5.01119599e-02, 0.00000000e+00, 1.74156665e-02, 0.00000000e+00,
#         6.42351103e-02, 6.16746883e-02, 7.26252617e-02, 0.00000000e+00,
#         4.55512952e-02, 3.38564563e-02, 0.00000000e+00, 0.00000000e+00,
#         1.60365486e-01, 3.93624891e-02, 0.00000000e+00, 3.43374527e-49,
#         3.06621268e-02, 1.13355358e-03, 0.00000000e+00, 0.00000000e+00,
#         6.92884691e-02, 2.97443992e-02, 1.25012788e-01, 0.00000000e+00,
#         0.00000000e+00, 9.23766863e-02, 3.69542243e-02, 2.72560639e-02,
#         0.00000000e+00, 0.00000000e+00, 4.66555323e-03, 7.83859238e-03,
#         0.00000000e+00, 2.58187758e-02, 6.59839806e-03, 0.00000000e+00,
#         1.92589944e-02, 0.00000000e+00, 8.56479953e-04, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.31439905e-05,
#         3.70241511e-03, 1.26317612e-02, 7.46505220e-02, 6.97702091e-04,
#         0.00000000e+00, 5.67053994e-02, 0.00000000e+00, 1.13355358e-03,
#         4.56052256e-02, 5.26621436e-03, 3.49751003e-02, 0.00000000e+00,
#         6.16374120e-03, 4.40734900e-01, 3.13035503e-02, 0.00000000e+00]])

# %%
for i, topic in enumerate(nmf_model.components_):
    print("THE TOP 15 WORDS FOR TOPIC # {}".format(i))
    print([tfidf.get_feature_names()[index]  for index in topic.argsort()[-15:]])
    print('\n')
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC # 0
# ['happy', 'hu', 'ho', 'mein', 'dekhna', 'pls', 'niki', 'na', 'time', 'js', 'home', 'come', 'hain', 'ac', 'ok']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 1
# ['gaye', 'wala', 'ko', 'nahin', 'bola', 'yeha', 'log', 'leke', 'hy', 'wo', 'bii', 'pass', 'thik', 'thk', 'haa']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 2
# ['painting', 'danger', 'dp', 'hu', 'nahi', 'raha', 'chal', 'aacha', 'padta', 'mei', 'thk', 'jio', 'mast', 'nahii', 'hy']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 3
# ['bol', 'js', 'nahii', 'acha', 'ek', 'tum', 'mein', 'tha', 'nikala', 'bhanje', 'pic', 'want', 'know', 'let', 'okay']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 4
# ['pic', 'time', 'peeche', 'bhi', 'nahi', 'aaj', 'boat', 'tera', 'ko', 'tha', 'bhej', 'wala', 'jio', 'pradnya', 'ka']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 5
# ['today', 'kab', 'ghar', 'cmg', 'thnx', 'know', 'mast', 'gaya', 'thank', 'yes', 'da', 'ko', 'bhanje', 'na', 'niki']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 6
# ['padta', 'nahi', 'uska', 'app', 'phir', 'gaya', 'editing', 'pass', 'kaunsa', 'nice', 'kiya', 'yeh', 'acha', 'hain', 'kya']

# %%
from utils.whatsapp import topic
df['Message_Prepared'] = df['Message_Only_Text']

# %% [markdown]
# #### <a>LDA</a>
# There is an abundance of methods with regards to topic modelling. Two, however, seem to be the most used: LDA and NMF. Sklearn has an implementation of both LDA and NMF.

# %%
topic.topics(df, model='lda', language="english")
# Out:
# ################
# ### Prakash😎 ###
# ################
#
#
# Topics in lda model:
# Topic #0: niki call missed ko voice dress mast
# Topic #1: ka na pradnya tera bhanje simmi pls
# Topic #2: ok hain kya nahi ka mein yes
# Topic #3: bhanje hi bhi come nice yeh toh
# Topic #4: acha hain kidar kya ne ja bahar
#
# ############
# ### Mami ###
# ############
#
#
# Topics in lda model:
# Topic #0: ka aacha wala hai kar nahin hu
# Topic #1: mei yeh week hu log painting gaye
# Topic #2: hy haa okay mast nahii ka chal
# Topic #3: mami se wo deko gaye ka happy
# Topic #4: nahii official hy website bii wo log

# %% [markdown]
# #### <a name="topic-nmf">5.3 NMF </a>
# [Back to Table of Contents](#table)
#
# An application of the NMF model used for topic modelling.

# %%
topic.topics(df, model='nmf', language="english")
# Out:
# ################
# ### Prakash😎 ###
# ################
#
#
# Topics in nmf model:
# Topic #0: ok hain na home js time come
# Topic #1: hain kya acha ka nahi yeh kaunsa
# Topic #2: niki da yes ko gaya na dress
# Topic #3: bhanje na thank know thnx kab pics
# Topic #4: call missed voice video kiya kya ka
#
# ############
# ### Mami ###
# ############
#
#
# Topics in nmf model:
# Topic #0: haa thk thik bii wo happy kar
# Topic #1: hy mast padta thk jio mei painting
# Topic #2: okay yeh mami kar ka jio hy
# Topic #3: nahii mei hu chal raha aacha thk
# Topic #4: ka jio time hai yeh kar wala

# %% [markdown]
# ## <a>Sentiment</a>

# %% [markdown]
# #### <a>Prepare Data</a>

# %%
# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# analyser = SentimentIntensityAnalyzer()
# df['Sentiment'] = df.apply(lambda row: analyser.polarity_scores(row.Message_Clean)["compound"], 1)

# %% [markdown]
# #### <a>Average Sentiment Per User</a>
#
#
# Prints the average sentiment per user to get an indication of positivity of that user.

# %%
from pattern.nl import sentiment  as sentiment_nl
df['Sentiment'] = df.apply(lambda row: sentiment_nl(row.Message_Clean)[0], 1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-6fac78f73d90> in <module>
# ----> 1 from pattern.nl import sentiment  as sentiment_nl
#       2 df['Sentiment'] = df.apply(lambda row: sentiment_nl(row.Message_Clean)[0], 1)
#
# ModuleNotFoundError: No module named 'pattern'

# %%
sentiment.print_avg_sentiment(df)
# Out:
# 			#######################
# 			## Average Sentiment ##
# 			#######################
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\watsapp\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sentiment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-097102c148f2> in <module>
# ----> 1 sentiment.print_avg_sentiment(df)
#
# ~\Desktop\Data_Science\Deep Learning\WatsApp Project\utils\whatsapp\sentiment.py in print_avg_sentiment(df)
#      61     print_title('Average Sentiment', 3)
#      62     for user in df.User.unique():
# ---> 63         avg_sentiment = round(np.mean(df[df.User == user]['Sentiment']), 3)
#      64         print('{0: <30}'.format(user + ':') + '\t\t' + str(avg_sentiment))
#      65     print('\n\n')
#
# ~\.conda\envs\watsapp\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\.conda\envs\watsapp\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'Sentiment'

# %% [markdown]
# #### <a>Plot Sentiment</a>
#
#
# The y-axis works as follows, a happy smiley indicates a score of 1 (max value) meaning a positive message and a sad smiley indicates a score of -1 (min value) meaning a negative message.

# %%
sentiment.plot_sentiment(df, colors=['#EAAA69','#5361A5'], savefig=False)

# %% [markdown]
# # <a>Word Clouds</a>

# %% [markdown]
# #### <a>Prepare Data</a>

# %%
user = "Prakash😎"
# Counts words and create dictionary of words with counts
counts = tf_idf.count_words_per_user(df,sentence_column="Message_Only_Text",user_column="User")
counts = tf_idf.remove_stopwords(counts, language="dutch", column="Word")
words = counts[["Word", user]].set_index('Word').to_dict()[user]

# %% [markdown]
# #### <a> Masked Word Cloud</a>

# %%
wordcloud.create_wordcloud(words,random_state=42, mask="../images/heart.jpg",
                           max_words=1000, max_font_size=50, scale=2, 
                           normalize_plurals=False, relative_scaling = 0.5)
# Out:
# <PIL.Image.Image image mode=RGBA size=720x652 at 0x1D046BB3438>

# %% [markdown]
# ## <a>Sentiment-based Word Cloud</a>

# %%
# Choose which user you want to see the word cloud for
positive, negative = wordcloud.extract_sentiment_count(counts, user = "Her")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-0336c5dc4c6f> in <module>
#       1 # Choose which user you want to see the word cloud for
# ----> 2 positive, negative = wordcloud.extract_sentiment_count(counts, user = "Her")
#
# ~\Desktop\Data_Science\Deep Learning\WatsApp Project\utils\whatsapp\wordcloud.py in extract_sentiment_count(counts, user)
#      89     """
#      90
# ---> 91     counts_dict = counts[['Word', user]].set_index('Word').to_dict()[user]
#      92     counts_dict = {key: value for key, value in counts_dict.items() if value > 0}
#      93
#
# ~\.conda\envs\watsapp\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\.conda\envs\watsapp\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\.conda\envs\watsapp\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['Her'] not in index"

# %% [markdown]
# ##### <a> Positive Words </a>

# %%
wordcloud.create_wordcloud(data=positive, cmap='Greens', mask='mask.png', 
                    stopwords='stopwords.txt', random_state=42, max_words=1000, 
                    max_font_size=50, scale=1.5, normalize_plurals=False, relative_scaling=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-83e5f17bde9c> in <module>
# ----> 1 wordcloud.create_wordcloud(data=positive, cmap='Greens', mask='mask.png',
#       2                     stopwords='stopwords.txt', random_state=42, max_words=1000,
#       3                     max_font_size=50, scale=1.5, normalize_plurals=False, relative_scaling=0.3)
#
# NameError: name 'positive' is not defined

# %% [markdown]
# ##### <a>Negative Words</a>

# %%
wordcloud.create_wordcloud(data=negative, cmap='Reds', mask='mask.png', 
                    stopwords='stopwords.txt', random_state=42, max_words=10000, 
                    max_font_size=50, scale=1.5, normalize_plurals=False, relative_scaling=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-ee15c4994fed> in <module>
# ----> 1 wordcloud.create_wordcloud(data=negative, cmap='Reds', mask='mask.png',
#       2                     stopwords='stopwords.txt', random_state=42, max_words=10000,
#       3                     max_font_size=50, scale=1.5, normalize_plurals=False, relative_scaling=0.3)
#
# NameError: name 'negative' is not defined

# %% [markdown]
# # <a>Picture Analysis</a>

# %% [markdown]
# #### <a>Extract Frequent Colors (k-Means)</a>

# %%
import os
import pickle

# %% [markdown]
# Below is the code to retrieve and dump the top 5 most frequent colors in an image using k-Means.
# It works as follows, each pixel in an image has its own color. That color of each pixel in an image is then extracted in an rgb format. This allows each pixel to have an x (r), y (g) and z (b) coordinate. After extracting all colors of each pixel, k-Means (with k=5) is then used to cluster the points into 5 colors. For each cluster the mediod is calculated and used as a representative of that cluster. Thus, you get top 5 colors for each image.

# %%
extract_colors = False

if extract_colors:
    # Get Top 5 Frequent Colors
    path = 'Images/'
    all_colors = [colors.get_common_colors(path + i) for i in os.listdir(path)]

    # Save colors
    with open('colors.pkl', 'wb') as f:
        pickle.dump(all_colors, f)

# %% [markdown]
# #### <a>Plot Frequent Colors</a>
#
#
# After getting the top 5 colors for each picture, they are counted and then displayed below in a histogram. The histogram is in a circular shape where larger/bigger/higher bars indicate colors that are more frequent in the set of pictures. There is a version of the histogram that only shows bars and one that shows a smoothened histogram to be more visually pleasing.

# %%
colors.plot_color('colors.pkl', smoothen=False, savefig=False)

# %%
colors.plot_color('colors.pkl', smoothen=True, savefig=False)
